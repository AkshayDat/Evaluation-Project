# %% [markdown]
# # Obejective : -->  This is a usecase where we aim to build and compare several customer churn prediction models

# %%
#importing libraries for visiualizing and understanding dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
tele_df=pd.read_csv('Telecom_customer_churn.csv')

# %% [markdown]
# # Finding insights of the data and what it consist of

# %%
tele_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
tele_df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#finding number of rows and columns present in the dataset
tele_df.shape
# Out:
# (7043, 21)

# %%
#finding the information about the dataset
tele_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#the dataset consist of more Object type data than numerical datatype

# %%
#finding the different gender values presnt in the dataset and their count
print(tele_df['gender'].unique())
print("\n")
print(tele_df['gender'].value_counts())
# Out:
# ['Female' 'Male']
#
#
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
#finding the different Partner values presnt in the dataset and their count
print(tele_df['Partner'].unique())
print("\n")
print(tele_df['Partner'].value_counts())
# Out:
# ['Yes' 'No']
#
#
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
#finding the different Dependents values presnt in the dataset and their count
print(tele_df['Dependents'].unique())
print("\n")
print(tele_df['Dependents'].value_counts())
# Out:
# ['No' 'Yes']
#
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
#finding the different PhoneService values presnt in the dataset and their count
print(tele_df['PhoneService'].unique())
print("\n")
print(tele_df['PhoneService'].value_counts())
# Out:
# ['No' 'Yes']
#
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
#finding the different MultipleLines values presnt in the dataset and their count
print(tele_df['MultipleLines'].unique())
print("\n")
print(tele_df['MultipleLines'].value_counts())
# Out:
# ['No phone service' 'No' 'Yes']
#
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
#finding the different InternetService values presnt in the dataset and their count
print(tele_df['InternetService'].unique())
print("\n")
print(tele_df['InternetService'].value_counts())
# Out:
# ['DSL' 'Fiber optic' 'No']
#
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
#finding the different OnlineSecurity values presnt in the dataset and their count
print(tele_df['OnlineSecurity'].unique())
print("\n")
print(tele_df['OnlineSecurity'].value_counts())
# Out:
# ['No' 'Yes' 'No internet service']
#
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
#finding the different OnlineBackup values presnt in the dataset and their count
print(tele_df['OnlineBackup'].unique())
print("\n")
print(tele_df['OnlineBackup'].value_counts())
# Out:
# ['Yes' 'No' 'No internet service']
#
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
#finding the different DeviceProtection values presnt in the dataset and their count
print(tele_df['DeviceProtection'].unique())
print("\n")
print(tele_df['DeviceProtection'].value_counts())
# Out:
# ['No' 'Yes' 'No internet service']
#
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
#finding the different TechSupport values presnt in the dataset and their count
print(tele_df['TechSupport'].unique())
print("\n")
print(tele_df['TechSupport'].value_counts())
# Out:
# ['No' 'Yes' 'No internet service']
#
#
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
#finding the different Contract values presnt in the dataset and their count
print(tele_df['Contract'].unique())
print("\n")
print(tele_df['Contract'].value_counts())
# Out:
# ['Month-to-month' 'One year' 'Two year']
#
#
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
#finding the different PaperlessBilling values presnt in the dataset and their count
print(tele_df['PaperlessBilling'].unique())
print("\n")
print(tele_df['PaperlessBilling'].value_counts())
# Out:
# ['Yes' 'No']
#
#
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
#finding the different PaymentMethod values presnt in the dataset and their count
print(tele_df['PaymentMethod'].unique())
print("\n")
print(tele_df['PaymentMethod'].value_counts())
# Out:
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
#
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
#finding the different Churn values presnt in the dataset and their count
print(tele_df['Churn'].unique())
print("\n")
print(tele_df['Churn'].value_counts())
# Out:
# ['No' 'Yes']
#
#
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
#converting total charges column datatype to float64
tele_df['TotalCharges'] = pd.to_numeric(tele_df['TotalCharges'],errors='coerce')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(tele_df.isnull())

# %%
#Cheking null values
tele_df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#as there is only one nan value in each column so dropping the whole row with nan column
tele_df=tele_df.dropna()

# %%
#Cheking null values again
plt.figure(figsize=(10,5))
sns.heatmap(tele_df.isnull())

# %%
tele_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#checking the shape of the data after removing the nan rows
tele_df.shape
# Out:
# (7032, 21)

# %%
#we can observe only one row got affected

# %% [markdown]
# # Bivariate Analysis

# %%
sns.countplot(tele_df['Churn'])
plt.title('Distribution of churn')
# Out:
# Text(0.5, 1.0, 'Distribution of churn')

# %%
sns.barplot(tele_df['Churn'],tele_df['tenure'])
plt.title('Churn W.R.T Tenure')
# Out:
# Text(0.5, 1.0, 'Churn W.R.T Tenure')

# %%
sns.scatterplot(tele_df['MultipleLines'],tele_df['Churn'])

# %%
sns.barplot(tele_df['Churn'],tele_df['MonthlyCharges'])
plt.title('Churn W.R.T MonthlyCharges')
# Out:
# Text(0.5, 1.0, 'Churn W.R.T MonthlyCharges')

# %%
sns.countplot(tele_df['Churn'],hue=tele_df['gender'])
plt.title('Distribution of churn gender wise')
# Out:
# Text(0.5, 1.0, 'Distribution of churn gender wise')

# %%
sns.countplot(tele_df['Churn'],hue=tele_df['SeniorCitizen'])
plt.title('Senior_Citizen who left and stayed')
# Out:
# Text(0.5, 1.0, 'Senior_Citizen who left and stayed')

# %%
sns.countplot(tele_df['Churn'],hue=tele_df['Partner'])
plt.title('Churn With W.R.T Customer having partner')
# Out:
# Text(0.5, 1.0, 'Churn With W.R.T Customer having partner')

# %%
plt.figure(figsize=(20,5))
sns.countplot(tele_df['tenure'])
plt.title('Tenure Count')
# Out:
# Text(0.5, 1.0, 'Tenure Count')

# %%
sns.scatterplot(tele_df['PhoneService'],tele_df['Churn'])

# %%
sns.pairplot(tele_df)

# %% [markdown]
# # Changing the categorical column 'values' to numeric 'values' using 'LABEL ENCODER'

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
tele_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
columns=(lb.fit_transform(tele_df['gender']),lb.fit_transform(tele_df['Partner']),
         lb.fit_transform(tele_df['Dependents']),lb.fit_transform(tele_df['PhoneService']),lb.fit_transform(tele_df['MultipleLines']),
         lb.fit_transform(tele_df['InternetService']),lb.fit_transform(tele_df['OnlineSecurity']),lb.fit_transform(tele_df['OnlineBackup']),
         lb.fit_transform(tele_df['DeviceProtection']),lb.fit_transform(tele_df['TechSupport']),lb.fit_transform(tele_df['StreamingTV']),
         lb.fit_transform(tele_df['StreamingMovies']),lb.fit_transform(tele_df['Contract']),lb.fit_transform(tele_df['PaperlessBilling']),
         lb.fit_transform(tele_df['PaymentMethod']),lb.fit_transform(tele_df['Churn']) )

# %%
tele_df['gender']=columns[0]
tele_df['Partner']=columns[1]
tele_df['Dependents']=columns[2]
tele_df['PhoneService']=columns[3]
tele_df['MultipleLines']=columns[4]
tele_df['InternetService']=columns[5]
tele_df['OnlineSecurity']=columns[6]
tele_df['OnlineBackup']=columns[7]
tele_df['DeviceProtection']=columns[8]
tele_df['TechSupport']=columns[9]
tele_df['StreamingTV']=columns[10]
tele_df['StreamingMovies']=columns[11]
tele_df['Contract']=columns[12]
tele_df['PaperlessBilling']=columns[13]
tele_df['PaymentMethod']=columns[14]
tele_df['Churn']=columns[15]

# %%
tele_df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
#dropping the customer_id column as it donot help in prediction
tele_df.drop(['customerID'],axis=1,inplace=True)

# %% [markdown]
# # Univariate Analysis

# %%
#using boxplot to see outliers and IQR range
collist=tele_df.columns.values
ncol=20
nrows=10
plt.figure(figsize=(50,150))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(tele_df[collist[i]],color='yellow',orient='v')

# %% [markdown]
# # Statistical Analysis

# %%
tele_df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7032.000000    7032.000000  7032.000000  7032.000000  7032.000000
# mean      0.504693       0.162400     0.482509     0.298493    32.421786
# std       0.500014       0.368844     0.499729     0.457629    24.545260
# min       0.000000       0.000000     0.000000     0.000000     1.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7032.000000    7032.000000      7032.000000     7032.000000
# mean       0.903299       0.940557         0.872582        0.789249
# std        0.295571       0.948627         0.737271        0.859962
# ...

# %%
plt.figure(figsize=(20,5))
sns.heatmap(tele_df.describe(), annot=True)

# %%
tele_cor=tele_df.corr()

# %%
tele_cor
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001819 -0.001379    0.010349  0.005285
# SeniorCitizen    -0.001819       1.000000  0.016957   -0.210550  0.015683
# Partner          -0.001379       0.016957  1.000000    0.452269  0.381912
# Dependents        0.010349      -0.210550  0.452269    1.000000  0.163386
# tenure            0.005285       0.015683  0.381912    0.163386  1.000000
# PhoneService     -0.007515       0.008392  0.018397   -0.001078  0.007877
# MultipleLines    -0.006908       0.146287  0.142717   -0.024975  0.343673
# InternetService  -0.002236      -0.032160  0.000513    0.044030 -0.029835
# OnlineSecurity   -0.014899      -0.127937  0.150610    0.151198  0.327283
# OnlineBackup     -0.011920      -0.013355  0.153045    0.090231  0.372434
# DeviceProtection  0.001348      -0.021124  0.165614    0.079723  0.372669
# TechSupport      -0.006695      -0.151007  0.126488    0.132530  0.324729
# ...

# %%
tele_cov=tele_df.cov()

# %%
plt.figure(figsize=(20,5))
sns.heatmap(tele_cor,annot=True)

# %%
plt.figure(figsize=(20,5))
sns.heatmap(tele_cov,annot=True)

# %%
#checking the skewness
tele_df.skew()
# Out:
# gender             -0.018776
# SeniorCitizen       1.831103
# Partner             0.070024
# Dependents          0.880908
# tenure              0.237731
# PhoneService       -2.729727
# MultipleLines       0.118623
# InternetService     0.205704
# OnlineSecurity      0.418619
# OnlineBackup        0.184089
# DeviceProtection    0.188013
# TechSupport         0.403966
# StreamingTV         0.029366
# StreamingMovies     0.013851
# Contract            0.635149
# PaperlessBilling   -0.377503
# PaymentMethod      -0.169388
# MonthlyCharges     -0.222103
# TotalCharges        0.961642
# Churn               1.060622
# dtype: float64

# %% [markdown]
# # Removing The outliers and Skewness

# %%
from scipy.stats import zscore
z=np.abs(zscore(tele_df))
print(z)
# Out:
# [[1.00943013 0.44032709 1.03561683 ... 1.16169394 0.99419409 0.60166339]
#  [0.99065797 0.44032709 0.9656081  ... 0.26087792 0.17373982 0.60166339]
#  [0.99065797 0.44032709 0.9656081  ... 0.36392329 0.95964911 1.66205891]
#  ...
#  [1.00943013 0.44032709 1.03561683 ... 1.17000405 0.85451414 0.60166339]
#  [0.99065797 2.27103902 1.03561683 ... 0.31916782 0.87209546 1.66205891]
#  [0.99065797 0.44032709 0.9656081  ... 1.35793167 2.01234407 0.60166339]]

# %%
threhold=3

# %%
print(np.where(z>3))#printing all the value position which are greater than the threshold value
# Out:
# (array([   0,    3,    7,   20,   27,   62,   81,   89,  103,  105,  107,
#         114,  116,  129,  131,  133,  168,  180,  185,  187,  206,  211,
#         215,  216,  217,  225,  236,  252,  255,  259,  260,  263,  272,
#         278,  303,  321,  324,  328,  348,  354,  358,  372,  376,  382,
#         387,  398,  424,  431,  435,  452,  465,  481,  494,  497,  543,
#         568,  595,  609,  615,  619,  633,  659,  666,  668,  673,  676,
#         687,  715,  717,  734,  763,  774,  782,  788,  792,  811,  827,
#         841,  845,  857,  864,  871,  873,  875,  882,  891,  915,  932,
#         938,  940,  957,  970, 1008, 1015, 1034, 1047, 1048, 1050, 1069,
#        1106, 1115, 1118, 1140, 1142, 1146, 1157, 1165, 1178, 1200, 1217,
#        1221, 1238, 1251, 1253, 1267, 1274, 1294, 1307, 1322, 1327, 1329,
#        1330, 1344, 1347, 1360, 1374, 1397, 1402, 1411, 1447, 1474, 1475,
#        1476, 1495, 1501, 1508, 1514, 1555, 1557, 1576, 1579, 1609, 1615,
# ...

# %%
z[0][5]#checking the above output result
# Out:
# 3.0563338283944432

# %%
z[3][5]#checking the above output result
# Out:
# 3.0563338283944432

# %%
tele_new=tele_df[(z<3).all(axis=1)]  #removing outliers

# %%
print("Shape of the dataset before removing outliers",tele_df.shape)
print("\n \n")
print("Shape of the dataset after removing the outliers",tele_new.shape)
# Out:
# Shape of the dataset before removing outliers (7032, 20)
#
#
#
# Shape of the dataset after removing the outliers (6352, 20)

# %%
#we are left with 6352 rows after removing outliers

# %%
#cheking skewness after removing outliers
tele_new.skew()
# Out:
# gender             -0.013858
# SeniorCitizen       1.821088
# Partner             0.057973
# Dependents          0.881771
# tenure              0.236305
# PhoneService        0.000000
# MultipleLines       0.131929
# InternetService     0.049796
# OnlineSecurity      0.423083
# OnlineBackup        0.169109
# DeviceProtection    0.183866
# TechSupport         0.410861
# StreamingTV        -0.002434
# StreamingMovies    -0.010346
# Contract            0.633437
# PaperlessBilling   -0.388846
# PaymentMethod      -0.168578
# MonthlyCharges     -0.400997
# TotalCharges        0.898862
# Churn               1.050872
# dtype: float64

# %%
#removing the Skewness
collist=tele_new.columns.values
for i in range(0,len(collist)):
    if tele_new.skew().loc[collist[i]]>0.55:
        tele_new[collist[i]]=np.sqrt(tele_new[collist[i]])

# %%
tele_new.skew()
# Out:
# gender             -0.013858
# SeniorCitizen       1.821088
# Partner             0.057973
# Dependents          0.881771
# tenure              0.236305
# PhoneService        0.000000
# MultipleLines       0.131929
# InternetService     0.049796
# OnlineSecurity      0.423083
# OnlineBackup        0.169109
# DeviceProtection    0.183866
# TechSupport         0.410861
# StreamingTV        -0.002434
# StreamingMovies    -0.010346
# Contract            0.347212
# PaperlessBilling   -0.388846
# PaymentMethod      -0.168578
# MonthlyCharges     -0.400997
# TotalCharges        0.284972
# Churn               1.050872
# dtype: float64

# %% [markdown]
# # Splitting the data into training and testing sets

# %%
x=tele_new.iloc[:,:-1]

# %%
x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1       1            0.0        0         0.0      34             1
# 2       1            0.0        0         0.0       2             1
# 4       0            0.0        0         0.0       2             1
# 5       0            0.0        0         0.0       8             1
# 6       1            0.0        0         1.0      22             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 1              0                0               2             0
# 2              0                0               2             2
# 4              0                1               0             0
# 5              2                1               0             0
# 6              2                1               0             2
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 1                 2            0            0                0       1.0
# ...

# %%
x.shape
# Out:
# (6352, 19)

# %%
y=tele_new.iloc[:,-1]

# %%
y.head()
# Out:
# 1    0.0
# 2    1.0
# 4    1.0
# 5    1.0
# 6    0.0
# Name: Churn, dtype: float64

# %%
y.shape
# Out:
# (6352,)

# %%
#Scaling the data in x
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)

# %%
x=df_x
print(x)
# Out:
# [[ 0.99309687 -0.44196502 -0.9714404  ...  1.33767743 -0.33807368
#    0.06815731]
#  [ 0.99309687 -0.44196502 -0.9714404  ...  1.33767743 -0.43992661
#   -1.25718491]
#  [-1.00695111 -0.44196502 -0.9714404  ...  0.40137693  0.11369332
#   -1.18043079]
#  ...
#  [-1.00695111 -0.44196502  1.02939923 ... -0.53492357  1.18150623
#    1.76502908]
#  [ 0.99309687  2.26262248  1.02939923 ...  1.33767743  0.23525971
#   -0.97220936]
#  [ 0.99309687 -0.44196502 -0.9714404  ... -1.47122407  1.26200289
#    1.64175442]]

# %%
import sklearn
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import GaussianNB  
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier  
from sklearn.neighbors import KNeighborsClassifier 

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve,auc

# %%
#finding best random state
max_score=0
final_rstate=0

for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    lg.score(x_train,y_train)
    pred=lg.predict(x_test)
    acc_score=accuracy_score(y_test,pred)
    print("Accuracy SCORE is equal to :",acc_score,"at random state",i)
    if acc_score > max_score:
        max_score=acc_score
        final_rstate=i
        
        
    
    
print("The maximum Accuracy_score is ",max_score, "at random state",final_rstate)
# Out:
# Accuracy SCORE is equal to : 0.8079345088161209 at random state 42
# Accuracy SCORE is equal to : 0.7991183879093199 at random state 43
# Accuracy SCORE is equal to : 0.792191435768262 at random state 44
# Accuracy SCORE is equal to : 0.8198992443324937 at random state 45
# Accuracy SCORE is equal to : 0.8104534005037783 at random state 46
# Accuracy SCORE is equal to : 0.8110831234256927 at random state 47
# Accuracy SCORE is equal to : 0.7877833753148614 at random state 48
# Accuracy SCORE is equal to : 0.7984886649874056 at random state 49
# Accuracy SCORE is equal to : 0.8148614609571788 at random state 50
# Accuracy SCORE is equal to : 0.8180100755667506 at random state 51
# Accuracy SCORE is equal to : 0.8110831234256927 at random state 52
# Accuracy SCORE is equal to : 0.8154911838790933 at random state 53
# Accuracy SCORE is equal to : 0.8091939546599496 at random state 54
# Accuracy SCORE is equal to : 0.8230478589420654 at random state 55
# ...

# %%
#finalizing the train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=55)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (4764, 19) (1588, 19) (4764,) (1588,)

# %% [raw]
# Testing the Algorithms and finding the the best parameters using Grid Search cv

# %%
#best parameter for Logistic Regression
from sklearn.model_selection import GridSearchCV
lrg=LogisticRegression()
parameters={'penalty':['l1','l2']}
gd=GridSearchCV(lrg,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'penalty': 'l2'}

# %%
from sklearn.model_selection import GridSearchCV
svc=SVC()
parameters={'kernel':('linear','rbf'), 'C':[1,10]}
gd=GridSearchCV(svc,parameters)
gd.fit(x_train,y_train)
gd.best_params_

# %%
from sklearn.model_selection import GridSearchCV
knn=KNeighborsClassifier()
parameters={'n_neighbors':(1,10)}
gd=GridSearchCV(knn,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'n_neighbors': 10}

# %%
from sklearn.model_selection import GridSearchCV
dtc=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy')}
gd=GridSearchCV(dtc,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
Model= []
score= []
cvs=[]
rocscore=[]
model=[LogisticRegression(penalty='l2'),DecisionTreeClassifier(criterion='entropy'),SVC(C=1,kernel='rbf'),KNeighborsClassifier(n_neighbors=10),GaussianNB()]
for models in model:
    print("\n")
    Model.append(models)
    models.fit(x_train,y_train)
    print(models)
    prediction=models.predict(x_test)
    print("\n")
    acc_score=accuracy_score(y_test,prediction)
    print("ACCURACY_SCORE =",acc_score)
    score.append(acc_score*100)
    print("\n")
    cv_score=cross_val_score(models,x,y,cv=10, scoring='accuracy').mean()
    print("CROSS_VAL_SCORE =",cv_score)
    cvs.append(cv_score*100)
    print("\n")
    false_positive_rate, true_positive_rate,  thresholds=roc_curve(y_test,prediction)
    roc_auc= auc(false_positive_rate, true_positive_rate)
    print("ROC_AUC_SCORE =",roc_auc)
    rocscore.append(roc_auc*100)
    print("\n")
    print(" \n Classification Report \n ",classification_report(y_test,prediction))
    print("\n")
    cm=confusion_matrix(y_test,prediction)
    print(cm)
    print("\n") 
    plt.figure(figsize=(10,30))
    plt.subplot(911)
    plt.title(models)
    print(sns.heatmap(cm,annot=True))   
    plt.subplot(912)
    plt.title(models)      
    plt.plot(false_positive_rate, true_positive_rate, label= "AUC = %0.2f" % roc_auc)
    plt.plot([0,1],[0,1],'r--') 
    plt.legend(loc='lower right')
    plt.ylabel("True positive rate")
    plt.xlabel("False positive rate")
    print("\n \n \n")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# ACCURACY_SCORE = 0.8230478589420654
#
#
# CROSS_VAL_SCORE = 0.8047848264249987
#
#
# ROC_AUC_SCORE = 0.7521946377001837
#
#
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88      1172
#          1.0       0.68      0.60      0.64       416
#
#     accuracy                           0.82      1588
#    macro avg       0.77      0.75      0.76      1588
# weighted avg       0.82      0.82      0.82      1588
#
#
#
# [[1056  116]
#  [ 165  251]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
#
#
#
# ...

# %%
outcome=pd.DataFrame({'Model':['LogisticRegression','DecisionTreeClassifier','SVC','KNeighborsClassifier','GaussianNB'],'Accuracy_Score':[0.8280,0.7474,0.8154,0.7959,0.7676],'Cross_Val_Sore':[0.8046,0.7348,0.7923,0.7833,0.7603],'Roc_Auc_Score':[0.7544,0.6777,0.6898,0.6871,0.7674]})
outcome

# %%
#Logistic regression is giving a good result therefore finalizing it

# %%
lrg=LogisticRegression(penalty='l2')
lrg.fit(x_train,y_train)
prediction=lrg.predict(x_test)
acc_score=accuracy_score(prediction,y_test)
print("Accuracy Score =", acc_score)
cv_score=cross_val_score(lrg,x,y,cv=10,scoring='accuracy').mean()
print("The Cross Val Score =", cv_score)
# Out:
# Accuracy Score = 0.8230478589420654
# The Cross Val Score = 0.8047848264249987

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier(base_estimator=lrg, n_estimators=500,random_state=0)
ada.fit(x_train,y_train)
print(ada.score(x_train,y_train))
pred=ada.predict(x_test)
print("Predicted result",pred)
print("\n \n")
print("Actual Result \n",y_test)

acc_score=accuracy_score(y_test,pred)
print("Accuracy Score =", acc_score)
cv_score=cross_val_score(lrg,x,y,cv=10,scoring='accuracy').mean()
print("The Cross Val Score =", cv_score)
# Out:
# 0.7995382031905961
# Predicted result [0. 0. 1. ... 1. 0. 0.]
#
#
#
# Actual Result
#  5045    0.0
# 379     0.0
# 6199    1.0
# 6329    0.0
# 419     1.0
#        ...
# 5340    0.0
# 2701    0.0
# 3224    1.0
# 21      0.0
# 1101    0.0
# Name: Churn, Length: 1588, dtype: float64
# Accuracy Score = 0.8236775818639799
# The Cross Val Score = 0.8047848264249987

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(random_state=0)
gbc.fit(x_train,y_train)
print(gbc.score(x_train,y_train))
gbcpred=gbc.predict(x_test)
acc_score=accuracy_score(y_test,gbcpred)
print("Accuracy Score =", acc_score)
cv_score=cross_val_score(gbc,x,y,cv=10,scoring='accuracy').mean()
print("The Cross Val Score =", cv_score)
# Out:
# 0.8234676742233418
# Accuracy Score = 0.820528967254408
# The Cross Val Score = 0.8073030258010201

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100, criterion='entropy',random_state=0)
rfc.fit(x_train,y_train)
print(rfc.score(x_train,y_train))
rfcpred=rfc.predict(x_test)
acc_score=accuracy_score(y_test,rfcpred)
print("Accuracy Score =", acc_score)
cv_score=cross_val_score(rfc,x,y,cv=10,scoring='accuracy').mean()
print("The Cross Val Score =", cv_score)
# Out:
# 0.998320738874895
# Accuracy Score = 0.8041561712846348
# The Cross Val Score = 0.7934502055167633

# %%
#logistic regression is giving a good result, hence saving it

# %%
from sklearn.externals import joblib
joblib.dump(lrg,"lrg_Telecommunication.pkl")
# Out:
# ['lrg_Telecommunication.pkl']
