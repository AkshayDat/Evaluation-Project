# %%
#importing libraries for visiualizing and understanding dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
rest_train_df=pd.read_excel('Rest_Data_Train.xlsx')
rest_test_df=pd.read_excel('Rest_Data_Test.xlsx')

# %% [markdown]
# # Finding insights of the data and what it consist of

# %%
print("TRAIN DATASET")
rest_train_df.head()
# Out:
# TRAIN DATASET
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# ...

# %%
rest_train_df.tail()
# Out:
#                    TITLE  RESTAURANT_ID  \
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 12685                       North Indian, Burger, Kebab
# 12686                                 Goan, Continental
# 12687          Finger Food, Continental, Asian, Chinese
# 12688  North Indian, South Indian, Chinese, Street Food
# 12689                             North Indian, Chinese
#
#                                                    TIME         CITY  \
# 12685  12noon – 12midnight (Mon, Tue, Wed, Thu, Sun)...    Hyderabad
# 12686   12noon – 1am (Mon-Fri),11am – 5pm, 7pm – 1am...       Mumbai
# 12687                        12noon – 12:30AM (Mon-Sun)  Navi Mumbai
# 12688                           6am – 10:45pm (Mon-Sun)      Chennai
# ...

# %%
print("TEST DATASET")
rest_test_df.head()
# Out:
# TEST DATASET
#            TITLE  RESTAURANT_ID                                      CUISINES  \
# 0  CASUAL DINING           4085         North Indian, Chinese, Mughlai, Kebab
# 1    QUICK BITES          12680  South Indian, Fast Food, Pizza, North Indian
# 2  CASUAL DINING           1411       North Indian, Seafood, Biryani, Chinese
# 3           None            204                                       Biryani
# 4    QUICK BITES          13453                          South Indian, Kerala
#
#                                                 TIME       CITY      LOCALITY  \
# 0                      12noon – 12midnight (Mon-Sun)      Noida     Sector 18
# 1                            7am – 12:30AM (Mon-Sun)     Mumbai    Grant Road
# 2                           11am – 11:30pm (Mon-Sun)     Mumbai  Marine Lines
# 3  9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...  Faridabad           NIT
# 4                              11am – 10pm (Mon-Sun)      Kochi        Kaloor
#
# ...

# %%
rest_test_df.tail()
# Out:
#               TITLE  RESTAURANT_ID  \
# 4226  CASUAL DINING           9057
# 4227           None           1247
# 4228    QUICK BITES           8617
# 4229    QUICK BITES           6485
# 4230    QUICK BITES           2421
#
#                                            CUISINES  \
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228                      Continental, North Indian
# 4229                               Rolls, Beverages
# 4230                                        Mughlai
#
#                                                    TIME         CITY  \
# 4226                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# 4227                               11am – 1am (Mon-Sun)    Bangalore
# 4228                         9:30am – 10:30pm (Mon-Sun)    Faridabad
# 4229  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...        Kochi
# 4230                                5pm – 1am (Mon-Sun)  Bandra West
#
# ...

# %% [markdown]
# # Attribute Information

# %% [markdown]
# TITLE: The feature of the restaurant which can help identify what and for whom it is suitable for.
#
# RESTAURANT_ID: A unique ID for each restaurant.
#
# CUISINES: The variety of cuisines that the restaurant offers.
#
# TIME: The open hours of the restaurant.
#
# CITY: The city in which the restaurant is located.
#
# LOCALITY: The locality of the restaurant.
#
# RATING: The average rating of the restaurant by customers.
#
# VOTES: The overall votes received by the restaurant.
#
# COST: The average cost of a two-person meal.

# %%
#finding the different title present in the train  dataset and their count
print(rest_train_df['TITLE'].unique())
print("\n")
print(rest_train_df['TITLE'].value_counts())
# Out:
# ['CASUAL DINING' 'CASUAL DINING,BAR' 'QUICK BITES' 'DESSERT PARLOR' 'CAFÉ'
#  'MICROBREWERY' 'QUICK BITES,BEVERAGE SHOP' 'CASUAL DINING,IRANI CAFE'
#  'BAKERY,QUICK BITES' 'None' 'BAR,CASUAL DINING' 'BAR' 'PUB'
#  'BEVERAGE SHOP' 'FINE DINING' 'CAFÉ,QUICK BITES'
#  'BEVERAGE SHOP,DESSERT PARLOR' 'SWEET SHOP,QUICK BITES'
#  'DESSERT PARLOR,SWEET SHOP' 'BAKERY' 'BAKERY,DESSERT PARLOR' 'BAR,LOUNGE'
#  'FOOD COURT' 'LOUNGE' 'DESSERT PARLOR,BEVERAGE SHOP'
#  'LOUNGE,CASUAL DINING' 'FOOD TRUCK' 'QUICK BITES,FOOD COURT' 'SWEET SHOP'
#  'BEVERAGE SHOP,FOOD COURT' 'PUB,CASUAL DINING' 'MESS'
#  'MICROBREWERY,CASUAL DINING' 'CASUAL DINING,SWEET SHOP' 'KIOSK'
#  'QUICK BITES,KIOSK' 'CLUB' 'FINE DINING,BAR' 'DESSERT PARLOR,QUICK BITES'
#  'FOOD COURT,QUICK BITES' 'LOUNGE,CAFÉ' 'BAKERY,CONFECTIONERY'
#  'CASUAL DINING,CAFÉ' 'DHABA' 'CAFÉ,DESSERT PARLOR'
#  'QUICK BITES,DESSERT PARLOR' 'PUB,MICROBREWERY' 'LOUNGE,BAR'
#  'DESSERT PARLOR,CAFÉ' 'CAFÉ,BAR' 'SWEET SHOP,CONFECTIONERY'
# ...

# %%
#finding the different title present in the test  dataset and their count
print(rest_test_df['TITLE'].unique())
print("\n")
print(rest_test_df['TITLE'].value_counts())
# Out:
# ['CASUAL DINING' 'QUICK BITES' 'None' 'FOOD TRUCK,DESSERT PARLOR'
#  'DESSERT PARLOR,QUICK BITES' 'CASUAL DINING,BAR' 'LOUNGE' 'BEVERAGE SHOP'
#  'CASUAL DINING,PUB' 'DESSERT PARLOR' 'PUB' 'CAFÉ' 'BAKERY' 'LOUNGE,BAR'
#  'BAKERY,QUICK BITES' 'SWEET SHOP' 'SWEET SHOP,QUICK BITES'
#  'BEVERAGE SHOP,QUICK BITES' 'CAFÉ,QUICK BITES' 'DHABA'
#  'QUICK BITES,DESSERT PARLOR' 'FINE DINING' 'IRANI CAFE,BAKERY'
#  'PUB,CASUAL DINING' 'BAKERY,CASUAL DINING' 'BAR' 'FOOD COURT'
#  'QUICK BITES,SWEET SHOP' 'CAFÉ,BAR' 'BAR,PUB' 'BAKERY,DESSERT PARLOR'
#  'KIOSK' 'CAFÉ,BAKERY' 'CASUAL DINING,BAKERY' 'BAKERY,CAFÉ'
#  'CASUAL DINING,CAFÉ' 'QUICK BITES,CAFÉ' 'MESS' 'BAR,CASUAL DINING'
#  'BEVERAGE SHOP,CAFÉ' 'BEVERAGE SHOP,DESSERT PARLOR' 'PUB,FINE DINING'
#  'CASUAL DINING,FOOD COURT' 'CAFÉ,CASUAL DINING' 'LOUNGE,CASUAL DINING'
#  'DESSERT PARLOR,CAFÉ' 'FINE DINING,BAR' 'CASUAL DINING,SWEET SHOP'
#  'LOUNGE,FINE DINING' 'MICROBREWERY,PUB' 'FOOD TRUCK'
# ...

# %%
#finding the different cusine offered by restraunts in the train  dataset and their count
print(rest_train_df['CUISINES'].unique())
print("\n")
print(rest_train_df['CUISINES'].value_counts())
# Out:
# ['Malwani, Goan, North Indian' 'Asian, Modern Indian, Japanese'
#  'North Indian, Chinese, Biryani, Hyderabadi' ...
#  'North Indian, Burger, Kebab' 'Goan, Continental'
#  'Finger Food, Continental, Asian, Chinese']
#
#
# South Indian                                                              532
# North Indian                                                              526
# North Indian, Chinese                                                     501
# Fast Food                                                                 286
# Chinese                                                                   167
#                                                                          ...
# Seafood, Biryani, Desserts, North Indian, Chinese, Hyderabadi, Mughlai      1
# Juices, Beverages, Cafe                                                     1
# Biryani, Chinese, South Indian                                              1
# ...

# %%
#finding the different cusine offered by restraunts in the test dataset and their count
print(rest_test_df['CUISINES'].unique())
print("\n")
print(rest_test_df['CUISINES'].value_counts())
# Out:
# ['North Indian, Chinese, Mughlai, Kebab'
#  'South Indian, Fast Food, Pizza, North Indian'
#  'North Indian, Seafood, Biryani, Chinese' ...
#  'North Indian, Chinese, Kebab, Juices' 'Sindhi, Street Food'
#  'Rolls, Beverages']
#
#
# North Indian, Chinese                                                      213
# North Indian                                                               190
# South Indian                                                               174
# Fast Food                                                                   78
# Chinese                                                                     59
#                                                                           ...
# Continental, American, Chinese, Finger Food                                  1
# Continental, Burger, Pizza, Juices                                           1
# South Indian, Chinese, Kerala                                                1
# ...

# %%
#finding the different city  in the train  dataset and their count
print(rest_train_df['CITY'].unique())
print("\n")
print(rest_train_df['CITY'].value_counts())
# Out:
# ['Thane' 'Chennai' 'Mumbai' 'Bangalore' 'Gurgaon' 'Hyderabad' 'Kochi'
#  'Thane West' 'Andheri Lokhandwala' 'New Delhi' 'Andheri West'
#  'Malad East' '682036' 'Bangalor' 'Navi Mumbai' 'Bandra West' 'Delhi'
#  'Noida' 'Bangalore-560066' 'Secunderabad' nan 'India' 'Madhuranagar'
#  'Chennai Teynampet' 'Faridabad' 'Chembur.' 'Maharashtra'
#  'opp gurudwara Shakurpur' 'Telagana Land Line:040-48507016' 'Ghaziabad'
#  'Karnataka' 'Kerala' 'Edappally' 'Kadavanthra' 'Ernakulam Circle kochi'
#  'Bengalore' 'Near Reliance Fresh' 'Kilpauk' 'Bengaluru' 'Kothaguda'
#  'Goregaon West' 'Banglore' 'Tamil Nadu' 'Kakkanad' 'Kochi Elamkulam'
#  'Outer Ring Road' 'Mulund East'
#  'Secunderabad main road near signal NMREC COLLEGE' 'Telangana'
#  'Ponnuruni Kochi' 'Gachibowli' 'Semmancheri'
#  '5th Main Teachers Colony Koramangala Block 1 Bangalore 560034'
#  'Mumbai Mahim' 'Powai (Next to Powai Plaza)' 'Dombivali East'
#  'Kochi Vyttila' 'Kandivali' 'Kochi Palarivattom' 'Dewan Rama Road'
# ...

# %%
#finding the different city  in the test  dataset and their count
print(rest_test_df['CITY'].unique())
print("\n")
print(rest_test_df['CITY'].value_counts())
# Out:
# ['Noida' 'Mumbai' 'Faridabad' 'Kochi' 'Hyderabad' 'Navi Mumbai' 'Chennai'
#  'New Delhi' 'Bangalore' 'Vasai Mumbai' 'Gurgaon' 'Palarivattom' 'Delhi'
#  'Ernakulam' 'Thane West' 'Ghaziabad' 'Chennai.' 'Thane' 'Telangana'
#  'Bandra West' 'Potheri' 'Panathur Main Road' 'Secunderabad' nan
#  'JP Nagar' 'Near Andheri West Station'
#  'opposite to western side of ITPL Service gate' 'Kalkaji' 'Bengaluru'
#  'APR Chambers' 'Tamil Nadu 600102' 'Andheri West' 'India'
#  'Serilingampally' 'Maharashtra.' 'Gandhinagar Rd'
#  'Near Andheri East Station' 'HSR Layout' 'Greater Noida' 'Uttar Pradesh'
#  'Dwarka' 'Velachery' 'Anna Nagar West' 'Indiranagar' 'Whitefield'
#  'Kochi Ravipuram' 'Kerala 682036' 'Madhapur' 'Hyderabad.'
#  'Mira Road Thane Mumbai' 'India Gate New Delhi' 'Bangalore - 560095'
#  '1st Stage' 'Sholinganallur. Chennai' 'Chennai (Above Bombay Brasserie)'
#  'Powai' 'Marathahalli' 'Kaloor' 'Chennai 37' 'kochi' 'Gurugram' '682024'
# ...

# %%
#the train datset has more number of citites as compared to test dataset

# %% [markdown]
# # Cleaning data of train dataset

# %%
#checking null values in train dataset
plt.figure(figsize=(20,5))
sns.heatmap(rest_train_df.isnull())

# %%
rest_train_df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              112
# LOCALITY           98
# RATING              2
# VOTES            1204
# COST                0
# dtype: int64

# %%
#combining city and loaclity as location and dropping both columns ("as the location comes under the city")
rest_train_df['Location']=rest_train_df['CITY']+' '+rest_train_df['LOCALITY']
rest_train_df.drop(columns=['CITY','LOCALITY'],axis=1,inplace=True)

# %%
rest_train_df.dropna(subset=['Location'],inplace=True)

# %%
rest_train_df.dropna(subset=['RATING'],inplace=True)

# %%
#cleaning Votes column and replacing nan values

rest_train_df['VOTES'].fillna('0',inplace =True) # -- Replacing nan values

#cleaning the Rating Column
rest_train_df['VOTES']=rest_train_df['VOTES'].str.strip("votes")
rest_train_df['VOTES']=rest_train_df['VOTES'].astype(float)

# %%
#rechecking the dataset for null values
rest_train_df.isnull().sum()
# Out:
# TITLE            0
# RESTAURANT_ID    0
# CUISINES         0
# TIME             0
# RATING           0
# VOTES            0
# COST             0
# Location         0
# dtype: int64

# %%
#rechecking null values in dataset
plt.figure(figsize=(20,5))
sns.heatmap(rest_train_df.isnull())

# %% [markdown]
# # Cleanng data of test dataset

# %%
#checking null values in test dataset
plt.figure(figsize=(20,5))
sns.heatmap(rest_test_df.isnull())

# %%
rest_test_df.isnull().sum()
# Out:
# TITLE              0
# RESTAURANT_ID      0
# CUISINES           0
# TIME               0
# CITY              35
# LOCALITY          30
# RATING             2
# VOTES            402
# dtype: int64

# %%
#combining city and loaclity as location and dropping both columns ("as the location comes under the city")
rest_test_df['Location']=rest_test_df['CITY']+' '+rest_test_df['LOCALITY']
rest_test_df.drop(columns=['CITY','LOCALITY'],axis=1,inplace=True)

# %%
rest_test_df.dropna(subset=['Location'],inplace=True)

# %%
rest_test_df.dropna(subset=['RATING'],inplace=True)

# %%
#cleaning votes column and replacing nan values

rest_test_df['VOTES'].fillna('0',inplace =True) # -- Replacing nan values

#cleaning the Rating Column
rest_test_df['VOTES']=rest_test_df['VOTES'].str.strip("votes")
rest_test_df['VOTES']=rest_test_df['VOTES'].astype(float)

# %%
#rechecking null values in test dataset
plt.figure(figsize=(20,5))
sns.heatmap(rest_test_df.isnull())

# %%
rest_test_df.isnull().sum()
# Out:
# TITLE            0
# RESTAURANT_ID    0
# CUISINES         0
# TIME             0
# RATING           0
# VOTES            0
# Location         0
# dtype: int64

# %% [markdown]
# # Now  CONCATINATING BOTH DATASET

# %%
#for differentiating between test and train data
rest_train_df["source"] = "train"
rest_test_df["source"] = "test"

# %%
rest_df = pd.concat([rest_train_df,rest_test_df])

# %%
rest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16769 entries, 0 to 4230
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TITLE          16769 non-null  object
#  1   RESTAURANT_ID  16769 non-null  int64
#  2   CUISINES       16769 non-null  object
#  3   TIME           16769 non-null  object
#  4   RATING         16769 non-null  object
#  5   VOTES          16769 non-null  float64
#  6   COST           12575 non-null  float64
#  7   Location       16769 non-null  object
#  8   source         16769 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
rest_df['RATING'].head(15)
# Out:
# 0     3.6
# 1     4.2
# 2     3.8
# 3     4.1
# 4     3.8
# 5     4.0
# 6     4.1
# 7     4.3
# 8     3.9
# 9     3.3
# 10    4.1
# 11    4.0
# 12    3.4
# 13      -
# 14    4.0
# Name: RATING, dtype: object

# %%
#finding if the dataset contains duplicate values
rest_df.duplicated().sum()
# Out:
# 26

# %%
#dropping the duplicates
rest_df=rest_df.drop_duplicates()

# %%
rest_df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# RATING              0
# VOTES               0
# COST             4193
# Location            0
# source              0
# dtype: int64

# %%
max_place_length=-1
for i in range(len(rest_df["CUISINES"])):
    temp=len(rest_df["CUISINES"].iloc[i].strip().upper().split(","))
    if temp>max_place_length:
        max_place_length=temp
print("Max qualification length is :{}".format(max_place_length))
# Out:
# Max qualification length is :8

# %%
#Partitioning CUISINES column into 8 
CUISINES_1=list()
CUISINES_2=list()
CUISINES_3=list()
CUISINES_4=list()
CUISINES_5=list()
CUISINES_6=list()
CUISINES_7=list()
CUISINES_8=list()



for i in range(len(rest_df["CUISINES"])):
    temp=rest_df["CUISINES"].iloc[i].split(",")
    try :
                CUISINES_1.append(temp[0].strip().upper())
    except :
                CUISINES_1.append('NONE')
    try :
                CUISINES_2.append(temp[1].strip().upper())
    except :
                CUISINES_2.append('NONE')
            
    try :
                CUISINES_3.append(temp[2].strip().upper())
    except :
                CUISINES_3.append('NONE')
            
    
    try :
                CUISINES_4.append(temp[3].strip().upper())
    except :
                CUISINES_4.append('NONE')
            
    try :
                CUISINES_5.append(temp[4].strip().upper())
    except :
                CUISINES_5.append('NONE')
                                       
                                       
    try :
                CUISINES_6.append(temp[5].strip().upper())
    except :
                CUISINES_6.append('NONE')     
                                       
    try :
                CUISINES_7.append(temp[6].strip().upper())
    except :
                CUISINES_7.append('NONE')
     
                                       
    try :
                CUISINES_8.append(temp[7].strip().upper())
    except :
                CUISINES_8.append('NONE')

# %%
rest_df["CUISINES_1"]=CUISINES_1
rest_df["CUISINES_2"]=CUISINES_2
rest_df["CUISINES_3"]=CUISINES_3
rest_df["CUISINES_4"]=CUISINES_4
rest_df["CUISINES_5"]=CUISINES_5
rest_df["CUISINES_6"]=CUISINES_6
rest_df["CUISINES_7"]=CUISINES_7
rest_df["CUISINES_8"]=CUISINES_8

# %%
#dropping  CUISINES column
rest_df.drop(['CUISINES'],axis=1,inplace=True)

# %%
rest_df.head()
# Out:
#                TITLE  RESTAURANT_ID                                    TIME  \
# 0      CASUAL DINING           9438  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)
# 1  CASUAL DINING,BAR          13198                    6pm – 11pm (Mon-Sun)
# 2      CASUAL DINING          10915     11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 3        QUICK BITES           6346                 11:30am – 1am (Mon-Sun)
# 4     DESSERT PARLOR          15387                    11am – 1am (Mon-Sun)
#
#   RATING  VOTES    COST              Location source    CUISINES_1  \
# 0    3.6   49.0  1200.0  Thane Dombivali East  train       MALWANI
# 1    4.2   30.0  1500.0     Chennai Ramapuram  train         ASIAN
# 2    3.8  221.0   800.0    Chennai Saligramam  train  NORTH INDIAN
# 3    4.1   24.0   800.0    Mumbai Bandra West  train       TIBETAN
# 4    3.8  165.0   300.0    Mumbai Lower Parel  train      DESSERTS
#
#       CUISINES_2    CUISINES_3  CUISINES_4 CUISINES_5 CUISINES_6 CUISINES_7  \
# ...

# %%
rest_df
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                                    TIME RATING  VOTES    COST  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    3.6   49.0  1200.0
# 1                                  6pm – 11pm (Mon-Sun)    4.2   30.0  1500.0
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)    3.8  221.0   800.0
# 3                               11:30am – 1am (Mon-Sun)    4.1   24.0   800.0
# 4                                  11am – 1am (Mon-Sun)    3.8  165.0   300.0
# ...

# %%
#after  CUISINES 3 dataset rarely consist of a value therefore dropping all the preeceding columns affft  CUISINES 3
rest_df.drop(['CUISINES_4','CUISINES_5','CUISINES_6','CUISINES_7','CUISINES_8'],axis=1,inplace=True)

# %%
rest_df
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                                    TIME RATING  VOTES    COST  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    3.6   49.0  1200.0
# 1                                  6pm – 11pm (Mon-Sun)    4.2   30.0  1500.0
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)    3.8  221.0   800.0
# 3                               11:30am – 1am (Mon-Sun)    4.1   24.0   800.0
# 4                                  11am – 1am (Mon-Sun)    3.8  165.0   300.0
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(20,55))
sns.barplot(rest_df['COST'],rest_df['TITLE'])
plt.title('Cost w.r.t. Title')
# Out:
# Text(0.5, 1.0, 'Cost w.r.t. Title')

# %%
sns.scatterplot(rest_df['VOTES'],rest_df['COST'])

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(rest_df['RATING'],rest_df['COST'])

# %%
plt.figure(figsize=(20,55))
sns.barplot(rest_df['COST'],rest_df['CUISINES_1'])
plt.title('Cost w.r.t. CUISINES_1')
# Out:
# Text(0.5, 1.0, 'Cost w.r.t. CUISINES_1')

# %%
plt.figure(figsize=(20,55))
sns.barplot(rest_df['COST'],rest_df['CUISINES_2'])
plt.title('Cost w.r.t. CUISINES_2')
# Out:
# Text(0.5, 1.0, 'Cost w.r.t. CUISINES_2')

# %%
plt.figure(figsize=(20,55))
sns.barplot(rest_df['COST'],rest_df['CUISINES_3'])
plt.title('Cost w.r.t. CUISINES_3')
# Out:
# Text(0.5, 1.0, 'Cost w.r.t. CUISINES_3')

# %%
plt.figure(figsize=(25,5))
sns.countplot(rest_df['TITLE'])

# %% [markdown]
# # Changing the categorical column 'values' to numeric 'values' using 'LABEL ENCODER'

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
columns=(lb.fit_transform(rest_df['TITLE']),lb.fit_transform(rest_df['Location']),lb.fit_transform(rest_df['CUISINES_1']),
        lb.fit_transform(rest_df['CUISINES_2']),lb.fit_transform(rest_df['CUISINES_3']))

# %%
rest_df['TITLE']=columns[0]
rest_df['Location']=columns[1]
rest_df['CUISINES_1']=columns[2]
rest_df['CUISINES_2']=columns[3]
rest_df['CUISINES_3']=columns[4]

# %%
#dropping time column
rest_df.drop(['TIME'],axis=1,inplace=True)

# %%
rest_df.head()
# Out:
#    TITLE  RESTAURANT_ID RATING  VOTES    COST  Location source  CUISINES_1  \
# 0     34           9438    3.6   49.0  1200.0      1868  train          61
# 1     36          13198    4.2   30.0  1500.0       455  train           6
# 2     34          10915    3.8  221.0   800.0       460  train          74
# 3    104           6346    4.1   24.0   800.0      1235  train         102
# 4     55          15387    3.8  165.0   300.0      1299  train          30
#
#    CUISINES_2  CUISINES_3
# 0          32          72
# 1          62          45
# 2          23          14
# 3          23          70
# 4          67          70

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
sns.boxplot(rest_df['TITLE'])

# %%
sns.boxplot(rest_df['RESTAURANT_ID'])

# %%
sns.boxplot(rest_df['VOTES'])

# %%
sns.boxplot(rest_df['COST'])

# %%
sns.boxplot(rest_df['Location'])

# %%
sns.boxplot(rest_df['CUISINES_1'])

# %%
sns.boxplot(rest_df['CUISINES_2'])

# %%
sns.boxplot(rest_df['CUISINES_3'])

# %% [markdown]
# # Statistical Analysis

# %%
rest_df.describe()
# Out:
#               TITLE  RESTAURANT_ID         VOTES          COST      Location  \
# count  16743.000000   16743.000000  16743.000000  12550.000000  16743.000000
# mean      64.845547    7761.981186    380.967569    656.358645    857.237532
# std       35.899888    4492.506626    811.889145    628.956065    524.221461
# min        0.000000       0.000000      0.000000     20.000000      0.000000
# 25%       34.000000    3867.500000     40.000000    300.000000    378.000000
# 50%       62.000000    7745.000000    133.000000    500.000000    837.000000
# 75%      104.000000   11665.500000    410.000000    800.000000   1290.000000
# max      122.000000   15573.000000  41186.000000  14000.000000   1949.000000
#
#          CUISINES_1    CUISINES_2    CUISINES_3
# count  16743.000000  16743.000000  16743.000000
# mean      50.935197     48.990085     57.987398
# std       28.919315     25.331057     22.522000
# min        0.000000      0.000000      0.000000
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(rest_df.describe(),annot=True)

# %%
rest_df.corr()
# Out:
#                   TITLE  RESTAURANT_ID     VOTES      COST  Location  \
# TITLE          1.000000      -0.001263 -0.133380 -0.265696 -0.006552
# RESTAURANT_ID -0.001263       1.000000  0.001027  0.042280  0.000343
# VOTES         -0.133380       0.001027  1.000000  0.256597  0.023895
# COST          -0.265696       0.042280  0.256597  1.000000  0.029460
# Location      -0.006552       0.000343  0.023895  0.029460  1.000000
# CUISINES_1     0.238389       0.047828 -0.040326 -0.035114  0.014597
# CUISINES_2     0.114198       0.013352 -0.049601 -0.033567  0.016311
# CUISINES_3     0.128001      -0.012733 -0.098024 -0.115758  0.026852
#
#                CUISINES_1  CUISINES_2  CUISINES_3
# TITLE            0.238389    0.114198    0.128001
# RESTAURANT_ID    0.047828    0.013352   -0.012733
# VOTES           -0.040326   -0.049601   -0.098024
# COST            -0.035114   -0.033567   -0.115758
# Location         0.014597    0.016311    0.026852
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(rest_df.corr(),annot=True)

# %%
rest_df.cov()
# Out:
#                      TITLE  RESTAURANT_ID          VOTES           COST  \
# TITLE          1288.801970  -2.036382e+02   -3887.578836   -5994.262913
# RESTAURANT_ID  -203.638195   2.018262e+07    3747.476095  119761.004634
# VOTES         -3887.578836   3.747476e+03  659163.984434  131458.849314
# COST          -5994.262913   1.197610e+05  131458.849314  395585.731511
# Location       -123.311536   8.070607e+02   10169.781088    9768.317840
# CUISINES_1      247.495904   6.213769e+03    -946.822434    -641.197287
# CUISINES_2      103.849801   1.519413e+03   -1020.103774    -533.901029
# CUISINES_3      103.493693  -1.288278e+03   -1792.409201   -1642.734306
#
#                     Location   CUISINES_1   CUISINES_2   CUISINES_3
# TITLE            -123.311536   247.495904   103.849801   103.493693
# RESTAURANT_ID     807.060735  6213.768940  1519.412727 -1288.278101
# VOTES           10169.781088  -946.822434 -1020.103774 -1792.409201
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(rest_df.cov(),annot=True)

# %%
#cheking the skewness
rest_df.skew()
# Out:
# TITLE            -0.050222
# RESTAURANT_ID     0.007989
# VOTES            12.670839
# COST              3.974220
# Location          0.116721
# CUISINES_1       -0.020356
# CUISINES_2       -0.091746
# CUISINES_3       -0.974553
# dtype: float64

# %%
rest_df.drop(['RATING'],axis=1,inplace=True)

# %%
#explitting test and train data
rest_train_df = rest_df[rest_df.source=="train"]
rest_test_df = rest_df[rest_df.source=="test"]

# %%
#cheking the final shape of the test data
rest_test_df.shape
# Out:
# (4193, 9)

# %%
rest_test_df.head()
# Out:
#    TITLE  RESTAURANT_ID      VOTES  COST  Location source  CUISINES_1  \
# 0     34           4085  23.748684   NaN      1695   test          74
# 1    104          12680   7.810250   NaN      1277   test          92
# 2     34           1411  18.708287   NaN      1312   test          74
# 3     95            204  38.013156   NaN       590   test          15
# 4    104          13453   4.795832   NaN      1085   test          92
#
#    CUISINES_2  CUISINES_3
# 0          23          67
# 1          28          78
# 2          84          14
# 3          67          70
# 4          48          70

# %%
#cheking the final shape of the train data
rest_train_df.shape
# Out:
# (12550, 9)

# %%
rest_train_df.head()
# Out:
#    TITLE  RESTAURANT_ID      VOTES       COST  Location source  CUISINES_1  \
# 0     34           9438   7.000000  34.641016      1868  train          61
# 1     36          13198   5.477226  38.729833       455  train           6
# 2     34          10915  14.866069  28.284271       460  train          74
# 3    104           6346   4.898979  28.284271      1235  train         102
# 4     55          15387  12.845233  17.320508      1299  train          30
#
#    CUISINES_2  CUISINES_3
# 0          32          72
# 1          62          45
# 2          23          14
# 3          23          70
# 4          67          70

# %%
#dropping time,cost and source from test dataset
rest_test_df.drop(['COST','source'],axis=1,inplace=True)

# %%
#dropping time, and source from train dataset
rest_train_df.drop(['source'],axis=1,inplace=True)

# %%
#seprating dependent and independent columns
y=rest_train_df['COST']
rest_train_df.drop(['COST'],axis=1,inplace=True)

# %%
x=rest_train_df.iloc[:,:]

# %%
x.head()
# Out:
#    TITLE  RESTAURANT_ID      VOTES  Location  CUISINES_1  CUISINES_2  \
# 0     34           9438   7.000000      1868          61          32
# 1     36          13198   5.477226       455           6          62
# 2     34          10915  14.866069       460          74          23
# 3    104           6346   4.898979      1235         102          23
# 4     55          15387  12.845233      1299          30          67
#
#    CUISINES_3
# 0          72
# 1          45
# 2          14
# 3          70
# 4          70

# %%
y.head()
# Out:
# 0    34.641016
# 1    38.729833
# 2    28.284271
# 3    28.284271
# 4    17.320508
# Name: COST, dtype: float64

# %%
#Scaling the data in x
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)

# %%
x=df_x
print(x)
# Out:
# [[-0.86227576  0.37350842 -0.60819059 ...  0.34841999 -0.67931827
#    0.62635139]
#  [-0.80651651  1.20842412 -0.7281531  ... -1.54607684  0.50702857
#   -0.57034656]
#  [-0.86227576  0.7014793   0.01148974 ...  0.79621016 -1.03522233
#   -1.94433309]
#  ...
#  [ 0.39230745  0.74988664  0.78286032 ... -0.51271493 -0.95613254
#   -2.3432324 ]
#  [-0.86227576 -0.36015154 -0.71400215 ...  0.79621016  1.49565094
#   -1.54543377]
#  [-0.86227576 -0.29442413  0.89012314 ...  0.79621016 -1.03522233
#    0.53770709]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR 
from sklearn.tree import DecisionTreeRegressor  
from sklearn.neighbors import KNeighborsRegressor

# %%
#Finding the best Random state

max_score=0
final_rstate=0

for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lm=LinearRegression() 
    lm.fit(x_train,y_train)
    lm.score(x_train,y_train)
    pred=lm.predict(x_test)
    r_score=r2_score(y_test,pred)
    print("R2 SCORE is equal to :",r_score,"at random state",i)
    
    if r_score > max_score:
        max_score=r_score
        final_rstate=i
print("The maximum r2_score is ",max_score, "at random state",final_rstate)
# Out:
# R2 SCORE is equal to : 0.24611884701524267 at random state 42
# R2 SCORE is equal to : 0.26339052904599447 at random state 43
# R2 SCORE is equal to : 0.27457509322267326 at random state 44
# R2 SCORE is equal to : 0.26019601224133493 at random state 45
# R2 SCORE is equal to : 0.2537281495166318 at random state 46
# R2 SCORE is equal to : 0.25255834152968826 at random state 47
# R2 SCORE is equal to : 0.2451743500600564 at random state 48
# R2 SCORE is equal to : 0.26503595659606105 at random state 49
# R2 SCORE is equal to : 0.24491993937309875 at random state 50
# R2 SCORE is equal to : 0.2623068896337337 at random state 51
# R2 SCORE is equal to : 0.25909632177507924 at random state 52
# R2 SCORE is equal to : 0.2650484805816935 at random state 53
# R2 SCORE is equal to : 0.23340171608020222 at random state 54
# R2 SCORE is equal to : 0.28209462687677245 at random state 55
# R2 SCORE is equal to : 0.28269263426058255 at random state 56
# ...

# %%
#finalizing the train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=56)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (9412, 7) (3138, 7) (9412,) (3138,)

# %%
#using Lasso, Ridge And Elastic net to overcome overfit and underfit situation

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
print("\n")
preed=ls.predict(x_test)
r_score=r2_score(y_test,preed)
print("The R2 score is",r_score)
# Out:
# 0.250737282394236
#
#
# The R2 score is 0.28269109153241556

# %%
ri=Ridge(alpha=0.001)
ri.fit(x_train,y_train)
print(ri.score(x_train,y_train))
print("\n")
predd=ri.predict(x_test)
r_score=r2_score(y_test,predd)
print("The r2_score is",r_score)
# Out:
# 0.25073728306551113
#
#
# The r2_score is 0.28269263121305743

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
r_score=r2_score(y_test,enrpred)
print("The r2_score is",r_score)
enr.coef_
# Out:
# 0.21137401579434856
# The r2_score is 0.2292522330958816
# array([-1.55287589,  0.        ,  2.08205715,  0.        , -0.        ,
#        -0.        , -0.35487333])

# %%
from sklearn.model_selection import GridSearchCV
dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae')}
gd=GridSearchCV(dtr,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'criterion': 'mse'}

# %%
from sklearn.model_selection import GridSearchCV
knr=KNeighborsRegressor()
parameters={'n_neighbors':(1,9)}
gd=GridSearchCV(knr,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'n_neighbors': 9}

# %%
from sklearn.model_selection import GridSearchCV
svr=SVR()
parameters={'kernel':('linear','poly','rbf')}
gd=GridSearchCV(svr,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
Model= []
score= []
cvs=[]
rocscore=[]
model=[LinearRegression(),SVR(kernel='rbf'),DecisionTreeRegressor(criterion='mse'),KNeighborsRegressor(n_neighbors=9)]
for models in model:
    print("\n")
    Model.append(models)
    models.fit(x_train,y_train)
    print(models)
    prediction=models.predict(x_test)
    print("\n")
    R2_score=r2_score(y_test,prediction)
    print("R2_SCORE =",R2_score)
    score.append(R2_score*100)
    print("\n")
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# R2_SCORE = 0.28269263426058255
#
#
#
#
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# R2_SCORE = 0.3445334204436268
#
#
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
#
#
# R2_SCORE = 0.4926770484066303
#
#
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                     weights='uniform')
#
#
# ...

# %%
#Decision Tree Regresor is giving Good result hence finalizing it

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor(base_estimator=dtr, n_estimators=500)
ada.fit(x_train,y_train)
print(ada.score(x_train,y_train))
pred=ada.predict(x_test)
print("Predicted result",pred)
print("\n \n")
print("Actual Result \n",y_test)
# Out:
# 0.999735107321038
# Predicted result [17.32050808 29.15475947 22.36067977 ... 17.32050808 24.49489743
#  28.28427125]
#
#
#
# Actual Result
#  7866     15.811388
# 12193    27.386128
# 11302    20.000000
# 10261    23.452079
# 9576     22.360680
#            ...
# 8372     18.708287
# 9065     26.457513
# 5790     12.247449
# 10054    24.494897
# 11378    28.284271
# Name: COST, Length: 3138, dtype: float64

# %%
r_score=r2_score(y_test,pred)
print("The r2_Score after apllying Boosting Technique for Linear _Regression is", r_score)
# Out:
# The r2_Score after apllying Boosting Technique for Linear _Regression is 0.7353964885990952

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr=GradientBoostingRegressor(n_estimators=500,max_depth= 4 ,min_samples_split= 5,learning_rate=0.1,loss='ls')
gbr.fit(x_train,y_train)
print(gbr.score(x_train,y_train))
gbrpred=gbr.predict(x_test)
R2_score=r2_score(gbrpred,y_test)
print("R2 Score =", R2_score)
# Out:
# 0.8617663534742906
# R2 Score = 0.6979810206787033

# %%
print("ERROR")


print("MEan Absolute error:",mean_absolute_error(y_test,pred))
print("Mean squared error:",mean_absolute_error(y_test,pred))

print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# ERROR
# MEan Absolute error: 3.444078025834308
# Mean squared error: 3.444078025834308
# Root mean squared error: 4.851684398809292

# %%
#As adaBoostRegressor is giving good result hence saving it

# %%
from sklearn.externals import joblib
joblib.dump(ada,"ada_rest_cost_Price.pkl")
# Out:
# ['ada_rest_cost_Price.pkl']
