# %% [markdown]
# # Objective :-- This is a usecase where we need to predict the claim amount in the Automobile insurance dataset.

# %%
#importing libraries for visiualizing and understanding dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
#loading the dataset
claim_df=pd.read_csv('Insurance_Claims_amount.csv')

# %% [markdown]
# # Finding insights of the data and what it consist of

# %%
claim_df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
claim_df.tail()
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#      Education Effective To Date EmploymentStatus  ...  \
# 9129  Bachelor           2/10/11         Employed  ...
# 9130   College           2/12/11         Employed  ...
# 9131  Bachelor            2/6/11       Unemployed  ...
# 9132   College            2/3/11         Employed  ...
# 9133   College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 9129                            89                          0
# ...

# %%
#finding the numbers of rows and column
claim_df.shape
# Out:
# (9134, 26)

# %%
#finding the information about the dataset
claim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
# ...

# %%
#the dataset consist of more Object type data than numerical datatype

# %%
#finding the different countries present in the dataset
print(claim_df['Country'].unique())
#finding their count
print(claim_df['Country'].value_counts())
# Out:
# ['US']
# US    9134
# Name: Country, dtype: int64

# %%
#finding the different state_code present in the dataset
print(claim_df['State Code'].unique())
#finding their count
print(claim_df['State Code'].value_counts())
# Out:
# ['KS' 'NE' 'OK' 'MO' 'IA']
# MO    3150
# IA    2601
# NE    1703
# OK     882
# KS     798
# Name: State Code, dtype: int64

# %%
#finding the different state present in the dataset
print(claim_df['State'].unique())
#finding their count
print(claim_df['State'].value_counts())
# Out:
# ['Kansas' 'Nebraska' 'Oklahoma' 'Missouri' 'Iowa']
# Missouri    3150
# Iowa        2601
# Nebraska    1703
# Oklahoma     882
# Kansas       798
# Name: State, dtype: int64

# %%
#finding the different Coverage_plan present in the dataset
print(claim_df['Coverage'].unique())
#finding their count
print(claim_df['Coverage'].value_counts())
# Out:
# ['Basic' 'Extended' 'Premium']
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64

# %%
#finding the different Education_Qualification  present in the dataset
print(claim_df['Education'].unique())
#finding their count
print(claim_df['Education'].value_counts())
# Out:
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64

# %%
#finding the different  EmploymentStatus present in the dataset
print(claim_df['EmploymentStatus'].unique())
#finding their count
print(claim_df['EmploymentStatus'].value_counts())
# Out:
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: EmploymentStatus, dtype: int64

# %%
#finding the different  Gender present in the dataset
print(claim_df['Gender'].unique())
#finding their count
print(claim_df['Gender'].value_counts())
# Out:
# ['F' 'M']
# F    4658
# M    4476
# Name: Gender, dtype: int64

# %%
#finding the different Location Code present in the dataset
print(claim_df['Location Code'].unique())
#finding their count
print(claim_df['Location Code'].value_counts())
# Out:
# ['Suburban' 'Rural' 'Urban']
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: Location Code, dtype: int64

# %%
#finding the different  Marital Status in the dataset
print(claim_df['Marital Status'].unique())
#finding their count
print(claim_df['Marital Status'].value_counts())
# Out:
# ['Married' 'Single' 'Divorced']
# Married     5298
# Single      2467
# Divorced    1369
# Name: Marital Status, dtype: int64

# %%
#finding the different  Policy Type in the dataset
print(claim_df['Policy Type'].unique())
#finding their count
print(claim_df['Policy Type'].value_counts())
# Out:
# ['Corporate Auto' 'Personal Auto' 'Special Auto']
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: Policy Type, dtype: int64

# %%
#finding the different  Policy in the dataset
print(claim_df['Policy'].unique())
#finding their count
print(claim_df['Policy'].value_counts())
# Out:
# ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: Policy, dtype: int64

# %%
#finding the different  Claim Reason in the dataset
print(claim_df['Claim Reason'].unique())
#finding their count
print(claim_df['Claim Reason'].value_counts())
# Out:
# ['Collision' 'Scratch/Dent' 'Hail' 'Other']
# Collision       3752
# Hail            2926
# Scratch/Dent    1432
# Other           1024
# Name: Claim Reason, dtype: int64

# %%
#finding the different  Sales Channel in the dataset
print(claim_df['Sales Channel'].unique())
#finding their count
print(claim_df['Sales Channel'].value_counts())
# Out:
# ['Agent' 'Call Center' 'Web' 'Branch']
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: Sales Channel, dtype: int64

# %%
#finding the different  Vehicle Class in the dataset
print(claim_df['Vehicle Class'].unique())
#finding their count
print(claim_df['Vehicle Class'].value_counts())
# Out:
# ['Two-Door Car' 'Four-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: Vehicle Class, dtype: int64

# %%
#finding the different  Vehicle Size in the dataset
print(claim_df['Vehicle Size'].unique())
#finding their count
print(claim_df['Vehicle Size'].value_counts())
# Out:
# ['Medsize' 'Small' 'Large']
# Medsize    6424
# Small      1764
# Large       946
# Name: Vehicle Size, dtype: int64

# %%
#checking Null values
sns.heatmap(claim_df.isnull())

# %%
claim_df.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
claim_df.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['State'],claim_df['Claim Amount'])
plt.title('Claim_Amount W.R.T State')
# Out:
# Text(0.5, 1.0, 'Claim_Amount W.R.T State')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Location Code'])
plt.title('Claim_Amount W.R.T Location')
# Out:
# Text(0.5, 1.0, 'Claim_Amount W.R.T Location')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Coverage'])
plt.title('Claim_Amount W.R.T Coverage')
# Out:
# Text(0.5, 1.0, 'Claim_Amount W.R.T Coverage')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['EmploymentStatus'])
plt.title('Claim_Amount W.R.T EmploymentStatus')
# Out:
# Text(0.5, 1.0, 'Claim_Amount W.R.T EmploymentStatus')

# %%
plt.figure(figsize=(20,5))
sns.countplot(claim_df['Number of Policies'], hue=claim_df['Policy'])
plt.title('Number Of Policy as per Policy ')
# Out:
# Text(0.5, 1.0, 'Number Of Policy as per Policy ')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Policy Type'])
plt.title('Claim_Amount W.R.T Policy Type')
# Out:
# Text(0.5, 1.0, 'Claim_Amount W.R.T Policy Type')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Sales Channel'])
plt.title('Claim_Amount as Per sales Channel')
# Out:
# Text(0.5, 1.0, 'Claim_Amount as Per sales Channel')

# %%
sns.scatterplot(claim_df['Claim Amount'], claim_df['Total Claim Amount'])

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Response'])
plt.title('Number of claim accepted or rejected ')
# Out:
# Text(0.5, 1.0, 'Number of claim accepted or rejected ')

# %%
plt.figure(figsize=(20,5))
sns.lineplot(claim_df['Income'],claim_df['Claim Amount'])

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(claim_df['Claim Reason'],claim_df['Response'])
plt.title('Response W.R.T Effective To Date ')
# Out:
# Text(0.5, 1.0, 'Response W.R.T Effective To Date ')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Claim Reason'])
plt.title('Claim Amount W.R.T to Claim Reason ')
# Out:
# Text(0.5, 1.0, 'Claim Amount W.R.T to Claim Reason ')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Vehicle Class'])
plt.title('Claim Amount W.R.T to Vehicle Class ')
# Out:
# Text(0.5, 1.0, 'Claim Amount W.R.T to Vehicle Class ')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Vehicle Size'])
plt.title('Claim Amount W.R.T to Vehicle Size ')
# Out:
# Text(0.5, 1.0, 'Claim Amount W.R.T to Vehicle Size ')

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(claim_df['Claim Reason'],claim_df['Vehicle Class'])
plt.title('Claim Reason W.R.T to Vehicle Class ')
# Out:
# Text(0.5, 1.0, 'Claim Reason W.R.T to Vehicle Class ')

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(claim_df['Claim Reason'],claim_df['Vehicle Size'])
plt.title('Claim Reason W.R.T to Vehicle Size ')
# Out:
# Text(0.5, 1.0, 'Claim Reason W.R.T to Vehicle Size ')

# %%
plt.figure(figsize=(20,5))
sns.boxplot(claim_df['Policy'],claim_df['Claim Amount'])
plt.title('Claim Amount W.R.T to Policy')
# Out:
# Text(0.5, 1.0, 'Claim Amount W.R.T to Policy')

# %%
plt.figure(figsize=(20,5))
sns.barplot(claim_df['Claim Amount'],claim_df['Policy'])
plt.title('Claim Amount W.R.T to Policy')
# Out:
# Text(0.5, 1.0, 'Claim Amount W.R.T to Policy')

# %% [markdown]
# # Changing the categorical column 'values' to numeric 'values' using 'LABEL ENCODER'

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
columns=(lb.fit_transform(claim_df['State']),lb.fit_transform(claim_df['Response']),lb.fit_transform(claim_df['Coverage']),
lb.fit_transform(claim_df['Effective To Date']),lb.fit_transform(claim_df['Gender']),lb.fit_transform(claim_df['Location Code']),
lb.fit_transform(claim_df['EmploymentStatus']),lb.fit_transform(claim_df['Policy Type']),lb.fit_transform(claim_df['Policy']),
lb.fit_transform(claim_df['Claim Reason']),lb.fit_transform(claim_df['Sales Channel']),lb.fit_transform(claim_df['Vehicle Class']),
lb.fit_transform(claim_df['Vehicle Size']))

# %%
claim_df['State']=columns[0]
claim_df['Response']=columns[1]
claim_df['Coverage']=columns[2]
claim_df['Effective To Date']=columns[3]
claim_df['Gender']=columns[4]
claim_df['Location Code']=columns[5]
claim_df['EmploymentStatus']=columns[6]
claim_df['Policy Type']=columns[7]
claim_df['Policy']=columns[8]
claim_df['Claim Reason']=columns[9]
claim_df['Sales Channel']=columns[10]
claim_df['Vehicle Class']=columns[11]
claim_df['Vehicle Size']=columns[12]

# %%
claim_df.tail()
# Out:
#      Customer Country State Code  State  Claim Amount  Response  Coverage  \
# 9129  LA72316      US         MO      2   2340.598798         0         0
# 9130  PK87824      US         MO      2    309.651122         1         1
# 9131  TD14365      US         MO      2    816.389043         0         1
# 9132  UP19263      US         MO      2    752.444244         0         1
# 9133  Y167826      US         MO      2    261.183687         0         1
#
#      Education  Effective To Date  EmploymentStatus  ...  \
# 9129  Bachelor                 32                 1  ...
# 9130   College                 34                 1  ...
# 9131  Bachelor                 55                 4  ...
# 9132   College                 52                 1  ...
# 9133   College                 36                 4  ...
#
#       Months Since Policy Inception  Number of Open Complaints  \
# 9129                             89                          0
# ...

# %%
claim_df.drop(['Customer','State Code','Country','Education','Marital Status'], axis=1, inplace= True)

# %%
claim_df.tail()
# Out:
#       State  Claim Amount  Response  Coverage  Effective To Date  \
# 9129      2   2340.598798         0         0                 32
# 9130      2    309.651122         1         1                 34
# 9131      2    816.389043         0         1                 55
# 9132      2    752.444244         0         1                 52
# 9133      2    261.183687         0         1                 36
#
#       EmploymentStatus  Gender  Income  Location Code  Monthly Premium Auto  \
# 9129                 1       1   71941              2                    73
# 9130                 1       0   21604              1                    79
# 9131                 4       1       0              1                    85
# 9132                 1       1   21941              1                    96
# 9133                 4       1       0              1                    77
#
#       ...  Months Since Policy Inception  Number of Open Complaints  \
# ...

# %%
claim_df.columns
# Out:
# Index(['State', 'Claim Amount', 'Response', 'Coverage', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %%
#using boxplot to see outliers and IQR range
collist=claim_df.columns.values
ncol=21
nrows=10
plt.figure(figsize=(50,150))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(claim_df[collist[i]],color='yellow',orient='v')

# %%
#checking the distribution
sns.distplot(claim_df['State'],color='Brown')

# %%
#checking the distribution
sns.distplot(claim_df['Claim Amount'],color='Brown')

# %%
#checking the distribution
sns.distplot(claim_df['Effective To Date'],color='Brown')

# %%
#checking the distribution
sns.distplot(claim_df['Income'],color='Brown')

# %%
#checking the distribution
sns.distplot(claim_df['Monthly Premium Auto'],color='Brown')

# %%
#checking the distribution
sns.distplot(claim_df['Months Since Last Claim'],color='Brown')

# %%
#checking the distribution
sns.distplot(claim_df['Months Since Policy Inception'],color='Brown')

# %%
#checking the distribution
plt.hist(claim_df['Number of Open Complaints'],color='Brown')
# Out:
# (array([7252.,    0., 1011.,    0.,  374.,    0.,  292.,    0.,  149.,
#           56.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
#checking the distribution
sns.distplot(claim_df['Total Claim Amount'],color='Brown')

# %% [markdown]
# # Statistical Analysis

# %%
claim_df.describe()
# Out:
#              State  Claim Amount     Response     Coverage  Effective To Date  \
# count  9134.000000   9134.000000  9134.000000  9134.000000        9134.000000
# mean      1.722684    800.494047     0.143201     0.480622          28.625575
# std       1.312397    687.096761     0.350297     0.655817          17.017215
# min       0.000000    189.800768     0.000000     0.000000           0.000000
# 25%       0.000000    399.425179     0.000000     0.000000          14.000000
# 50%       2.000000    578.018220     0.000000     0.000000          28.000000
# 75%       3.000000    896.216704     0.000000     1.000000          44.000000
# max       4.000000   8332.538119     1.000000     2.000000          58.000000
#
#        EmploymentStatus       Gender        Income  Location Code  \
# count       9134.000000  9134.000000   9134.000000    9134.000000
# mean           1.825706     0.490037  37657.380009       0.979089
# std            1.347793     0.499928  30379.904734       0.605732
# ...

# %%
plt.figure(figsize=(20,5))
sns.heatmap(claim_df.describe(),annot=True)

# %%
claim_cor=claim_df.corr()

# %%
claim_cor
# Out:
#                                   State  Claim Amount  Response  Coverage  \
# State                          1.000000     -0.006629 -0.001732  0.007558
# Claim Amount                  -0.006629      1.000000 -0.008930  0.168040
# Response                      -0.001732     -0.008930  1.000000  0.000642
# Coverage                       0.007558      0.168040  0.000642  1.000000
# Effective To Date             -0.000448     -0.012978 -0.043133  0.005482
# EmploymentStatus              -0.004054     -0.034846 -0.016703  0.003239
# Gender                         0.000545     -0.013610  0.004396 -0.014448
# Income                         0.002682      0.024366  0.011932 -0.010646
# Location Code                  0.001382      0.004854  0.001729 -0.020176
# Monthly Premium Auto          -0.005549      0.396262  0.010966  0.458997
# Months Since Last Claim        0.009249      0.011517 -0.016597  0.016925
# Months Since Policy Inception -0.004459      0.009418  0.002952  0.010658
# ...

# %%
plt.figure(figsize=(25,11))
sns.heatmap(claim_cor,annot=True)

# %%
#checking the skewness
claim_df.skew()
# Out:
# State                            0.021065
# Claim Amount                     3.032280
# Response                         2.037567
# Coverage                         1.031310
# Effective To Date                0.033899
# EmploymentStatus                 0.832147
# Gender                           0.039866
# Income                           0.286887
# Location Code                    0.009511
# Monthly Premium Auto             2.123546
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Policy Type                     -0.468383
# Policy                          -0.427639
# Claim Reason                     0.733526
# Sales Channel                    0.506774
# Total Claim Amount               1.714966
# Vehicle Class                    0.395146
# Vehicle Size                     0.072742
# dtype: float64

# %% [markdown]
# # Removing The outliers and Skewness

# %%
from scipy.stats import zscore
z=np.abs(zscore(claim_df))
print(z)
# Out:
# [[0.55068994 0.76287773 0.40882171 ... 0.16963969 1.49918077 0.16668206]
#  [0.97332215 0.14924546 0.40882171 ... 2.400737   0.91292371 0.16668206]
#  [1.73532819 0.71063622 0.40882171 ... 0.45573376 1.49918077 0.16668206]
#  ...
#  [0.21131611 0.02313483 0.40882171 ... 1.22793667 0.91292371 0.16668206]
#  [0.21131611 0.06993547 0.40882171 ... 0.88511256 0.91292371 2.0278971 ]
#  [0.21131611 0.78495478 0.40882171 ... 0.22200449 1.49918077 0.16668206]]

# %%
threhold=3

# %%
print(np.where(z>3))#printing all the value position which are greater than the threshold value
# Out:
# (array([  31,   50,   51,   79,   86,  125,  181,  185,  196,  196,  232,
#         243,  244,  248,  248,  266,  274,  281,  292,  303,  315,  316,
#         373,  375,  385,  386,  403,  404,  404,  407,  408,  418,  425,
#         435,  444,  496,  496,  510,  512,  522,  522,  541,  541,  554,
#         581,  581,  626,  633,  645,  680,  681,  702,  727,  749,  755,
#         757,  810,  814,  817,  820,  832,  832,  832,  836,  840,  856,
#         869,  873,  888,  888,  899,  914,  926,  944,  949, 1002, 1008,
#        1011, 1046, 1046, 1058, 1071, 1078, 1078, 1109, 1113, 1120, 1133,
#        1158, 1174, 1179, 1184, 1200, 1212, 1233, 1240, 1283, 1292, 1292,
#        1300, 1305, 1312, 1312, 1319, 1330, 1364, 1382, 1383, 1383, 1384,
#        1392, 1393, 1408, 1421, 1429, 1436, 1466, 1504, 1506, 1516, 1516,
#        1521, 1529, 1534, 1541, 1552, 1552, 1555, 1558, 1592, 1626, 1640,
#        1657, 1687, 1795, 1796, 1796, 1809, 1812, 1819, 1819, 1823, 1824,
# ...

# %%
z[31][9]#checking the above output result
# Out:
# 4.178932721080021

# %%
z[125][1]#checking the above output result
# Out:
# 3.3791570493636702

# %%
claim_new=claim_df[(z<3).all(axis=1)]  #removing outliers

# %%
print("Shape of the dataset before removing outliers",claim_df.shape)
print("\n \n")
print("Shape of the dataset after removing the outliers",claim_new.shape)
# Out:
# Shape of the dataset before removing outliers (9134, 21)
#
#
#
# Shape of the dataset after removing the outliers (8470, 21)

# %%
#we are left with 8470 rows after removing the outliers

# %%
#cheking skewness after removing outliers
claim_new.skew()
# Out:
# State                            0.019194
# Claim Amount                     1.848796
# Response                         2.030625
# Coverage                         1.080580
# Effective To Date                0.031848
# EmploymentStatus                 0.844023
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Monthly Premium Auto             1.330466
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        2.574570
# Number of Policies               1.226531
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.725402
# Sales Channel                    0.503296
# Total Claim Amount               0.709643
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
#removing the Skewness
collist=claim_new.columns.values
for i in range(0,len(collist)):
    if claim_new.skew().loc[collist[i]]>0.55:
        claim_new[collist[i]]=np.sqrt(claim_new[collist[i]])

# %%
claim_new.skew()
# Out:
# State                            0.019194
# Claim Amount                     1.069550
# Response                         2.030625
# Coverage                         0.637514
# Effective To Date                0.031848
# EmploymentStatus                 0.096940
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Monthly Premium Auto             0.973258
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        1.871949
# Number of Policies               0.834717
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.024930
# Sales Channel                    0.503296
# Total Claim Amount              -0.336015
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
#removing the Skewness
collist=claim_new.columns.values
for i in range(0,len(collist)):
    if claim_new.skew().loc[collist[i]]>0.55:
        claim_new[collist[i]]=np.sqrt(claim_new[collist[i]])

# %%
claim_new.skew()
# Out:
# State                            0.019194
# Claim Amount                     0.700818
# Response                         2.030625
# Coverage                         0.534893
# Effective To Date                0.031848
# EmploymentStatus                 0.096940
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Monthly Premium Auto             0.823548
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        1.669104
# Number of Policies               0.626026
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.024930
# Sales Channel                    0.503296
# Total Claim Amount              -0.336015
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
#almost the skewness is removed

# %% [markdown]
# # Splitting the data into training and testing sets

# %%
y=claim_new['Claim Amount']

# %%
claim_new.drop(['Claim Amount'],axis=1,inplace=True)

# %%
claim_new.head()
# Out:
#    State  Response  Coverage  Effective To Date  EmploymentStatus  Gender  \
# 0      1       0.0  0.000000                 47               1.0       0
# 1      3       0.0  1.000000                 24               2.0       0
# 2      4       0.0  1.189207                 41               1.0       0
# 3      2       0.0  0.000000                 12               2.0       1
# 4      1       0.0  0.000000                 52               1.0       1
#
#    Income  Location Code  Monthly Premium Auto  Months Since Last Claim  \
# 0   56274              1              2.882121                       32
# 1       0              1              3.113737                       13
# 2   48767              1              3.223710                       18
# 3       0              1              3.208680                       18
# 4   43836              0              2.923013                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# ...

# %%
x=claim_new.iloc[:,:]

# %%
x.shape
# Out:
# (8470, 20)

# %%
x.head()
# Out:
#    State  Response  Coverage  Effective To Date  EmploymentStatus  Gender  \
# 0      1       0.0  0.000000                 47               1.0       0
# 1      3       0.0  1.000000                 24               2.0       0
# 2      4       0.0  1.189207                 41               1.0       0
# 3      2       0.0  0.000000                 12               2.0       1
# 4      1       0.0  0.000000                 52               1.0       1
#
#    Income  Location Code  Monthly Premium Auto  Months Since Last Claim  \
# 0   56274              1              2.882121                       32
# 1       0              1              3.113737                       13
# 2   48767              1              3.223710                       18
# 3       0              1              3.208680                       18
# 4   43836              0              2.923013                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# ...

# %%
y.shape
# Out:
# (8470,)

# %%
y.head()
# Out:
# 0    4.077234
# 1    5.139923
# 2    5.991583
# 3    5.258436
# 4    4.095615
# Name: Claim Amount, dtype: float64

# %%
#the data in x is already scaled therefore skipping scaling of the data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR 
from sklearn.tree import DecisionTreeRegressor  
from sklearn.neighbors import KNeighborsRegressor

# %%
#Finding the best Random state

max_score=0
final_rstate=0

for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lm=LinearRegression() 
    lm.fit(x_train,y_train)
    lm.score(x_train,y_train)
    pred=lm.predict(x_test)
    r_score=r2_score(y_test,pred)
    print("R2 SCORE is equal to :",r_score,"at random state",i)
    
    if r_score > max_score:
        max_score=r_score
        final_rstate=i
print("The maximum r2_score is ",max_score, "at random state",final_rstate)
# Out:
# R2 SCORE is equal to : 0.25365976695996717 at random state 42
# R2 SCORE is equal to : 0.2578772544087381 at random state 43
# R2 SCORE is equal to : 0.22754783562797465 at random state 44
# R2 SCORE is equal to : 0.2678089915076082 at random state 45
# R2 SCORE is equal to : 0.24721435390277502 at random state 46
# R2 SCORE is equal to : 0.23935041512693933 at random state 47
# R2 SCORE is equal to : 0.2508922070054257 at random state 48
# R2 SCORE is equal to : 0.25295189612626146 at random state 49
# R2 SCORE is equal to : 0.26250337232614473 at random state 50
# R2 SCORE is equal to : 0.21461357458002017 at random state 51
# R2 SCORE is equal to : 0.23405696118000074 at random state 52
# R2 SCORE is equal to : 0.23989815357058308 at random state 53
# R2 SCORE is equal to : 0.24501780510424664 at random state 54
# R2 SCORE is equal to : 0.2078374300653686 at random state 55
# R2 SCORE is equal to : 0.23456391720363123 at random state 56
# ...

# %%
#finalizing the train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=83)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (6352, 20) (2118, 20) (6352,) (2118,)

# %%
from sklearn.model_selection import GridSearchCV
dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae')}
gd=GridSearchCV(dtr,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'criterion': 'friedman_mse'}

# %%
from sklearn.model_selection import GridSearchCV
knr=KNeighborsRegressor()
parameters={'n_neighbors':(1,10)}
gd=GridSearchCV(knr,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'n_neighbors': 10}

# %%
from sklearn.svm import SVR
svr=SVR(kernel="linear")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

#svr=SVR(kernel="poly")
#svr.fit(x_train,y_train)
#svr.score(x_train,y_train)
#pred_y=svr.predict(x_test)

#svr=SVR(kernel="rbf")
#svr.fit(x_train,y_train)
#svr.score(x_train,y_train)
#pred_y=svr.predict(x_test)

# %%
Model= []
score= []
cvs=[]
rocscore=[]
model=[LinearRegression(),DecisionTreeRegressor(criterion='friedman_mse'),KNeighborsRegressor(n_neighbors=10)]
for models in model:
    print("\n")
    Model.append(models)
    models.fit(x_train,y_train)
    print(models)
    prediction=models.predict(x_test)
    print("\n")
    R2_score=r2_score(y_test,prediction)
    print("R2_SCORE =",R2_score)
    score.append(R2_score*100)
    print("\n")
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# R2_SCORE = 0.2737470867379491
#
#
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='friedman_mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
#
#
# R2_SCORE = 0.7712839599483774
#
#
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')
#
#
# R2_SCORE = -0.014852050986512655

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
print("\n")
preed=ls.predict(x_test)
r_score=r2_score(y_test,preed)
print("The R2 score is",r_score)
# Out:
# 0.23975961064315987
#
#
# The R2 score is 0.2736988654276682

# %%
ri=Ridge(alpha=0.001)
ri.fit(x_train,y_train)
print(ri.score(x_train,y_train))
print("\n")
predd=ri.predict(x_test)
r_score=r2_score(y_test,predd)
print("The r2_score is",r_score)
# Out:
# 0.23976171882426534
#
#
# The r2_score is 0.2737470149963368

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
r_score=r2_score(y_test,enrpred)
print("The r2_score is",r_score)
enr.coef_
# Out:
# 0.010850419927148414
# The r2_score is 0.013184755786963653
# array([-0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  1.34164935e-06, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  4.62582795e-03,  0.00000000e+00,  0.00000000e+00])

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor(base_estimator=dtr, n_estimators=500)
ada.fit(x_train,y_train)
ada.score(x_train,y_train)
# Out:
# 0.998952389256113

# %%
pred=ada.predict(x_test)
print("Predicted result",pred)
print("\n \n")
print("Actual Price \n",y_test)
# Out:
# Predicted result [4.66739571 5.76841945 4.31461768 ... 6.35937918 3.9377743  4.85784894]
#
#
#
# Actual Price
#  5730    4.603791
# 1437    5.683809
# 6496    4.342154
# 8397    3.974952
# 7918    5.410497
#           ...
# 622     4.843847
# 5442    4.658154
# 3479    6.448217
# 5167    3.919237
# 7097    4.880144
# Name: Claim Amount, Length: 2118, dtype: float64

# %%
r_score=r2_score(y_test,pred)
print("The r2_Score after apllying Boosting Technique for Linear _Regression is", r_score)
# Out:
# The r2_Score after apllying Boosting Technique for Linear _Regression is 0.8805670231193784

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()

# %%
gbr=GradientBoostingRegressor(n_estimators=500,max_depth= 4 ,min_samples_split= 5,learning_rate=0.1,loss='ls')
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
# Out:
# 0.9529985900732961

# %%
gbrpred=gbr.predict(x_test)
R2_score=r2_score(gbrpred,y_test)
print("R2 Score =", R2_score)
# Out:
# R2 Score = 0.8736581934754266

# %%
#As Decision tree classifier is giving good result finalizing it using Adaboost

# %%
dtr=DecisionTreeRegressor(criterion='friedman_mse')
dtr.fit(x_train,y_train)
print(dtr.score(x_train,y_train))
dtrpred=dtr.predict(x_test)
R2_Score=r2_score(dtrpred,y_test)
print("\n")
print("R2_score is ", R2_Score)
# Out:
# 0.9999999932320686
#
#
# R2_score is  0.7935931782158682

# %%
ada=AdaBoostRegressor(base_estimator=dtr, n_estimators=500)
ada.fit(x_train,y_train)
ada.score(x_train,y_train)
pred=ada.predict(x_test)
print("Predicted result",pred)
print("\n \n")
print("Actual Price \n",y_test)
r_score=r2_score(y_test,pred)
print("\n \n")
print("The r2_Score after apllying Boosting Technique for Linear _Regression is", r_score)
# Out:
# Predicted result [4.66960049 5.84619753 4.31601157 ... 6.35206487 3.93442834 4.85974177]
#
#
#
# Actual Price
#  5730    4.603791
# 1437    5.683809
# 6496    4.342154
# 8397    3.974952
# 7918    5.410497
#           ...
# 622     4.843847
# 5442    4.658154
# 3479    6.448217
# 5167    3.919237
# 7097    4.880144
# Name: Claim Amount, Length: 2118, dtype: float64
#
#
#
# The r2_Score after apllying Boosting Technique for Linear _Regression is 0.8798570111342232

# %%
print("ERROR")


print("MEan Absolute error:",mean_absolute_error(y_test,pred))
print("Mean squared error:",mean_absolute_error(y_test,pred))

print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# ERROR
# MEan Absolute error: 0.10079784818389355
# Mean squared error: 0.10079784818389355
# Root mean squared error: 0.26360666379482706

# %%
from sklearn.externals import joblib
joblib.dump(ada,"ada_insuarance_claim.pkl")
# Out:
# ['ada_insuarance_claim.pkl']
